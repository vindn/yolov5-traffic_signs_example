# %%
# Os arquivos train.py e detect.py sao do YOLOv5
# no dataset de placas foram criados os labels e convertidos para o formato do YOLOv5
# se nao tiver o wandb instalado tirar do comando o wandb disabled
# após o treinamento os pesos serão salvo na pasta yolov5/runs/train, vericar o numero da rodada no final da execucao do treinamento
# !wandb disabled; python3 yolov5/train.py --img 412 --batch 16 --epochs 10 --data data.yaml --cache
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# W&B disabled.
# /usr/lib/python3/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=16, imgsz=412, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=True, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# ...

# %%
# Predicao de uma placa utilizando os pesos do treinamento anterior

import cv2
import torch
from PIL import Image

model = torch.hub.load('ultralytics/yolov5', 'custom', './runs/train/exp11/weights/best.pt')

img1 = Image.open('road197.png')  # PIL image
imgs = [img1]  # lista de imagens

# Inference
results = model(imgs, size=416)  # includes NMS

# Results
results.print()  
results.save()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Using cache found in /home/vindn/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2021-7-15 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce GTX 1060 3GB, 3019.0625MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7062001 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 400x300 1 speedlimit
# Speed: 9.2ms pre-process, 16.8ms inference, 1.8ms NMS per image at shape (1, 3, 416, 320)
# Saved road197.jpg to runs/hub/exp
#          xmin        ymin        xmax        ymax  confidence  class  \
# 0  204.326935  125.240387  246.634628  167.788467    0.376465      1
#
#          name
# 0  speedlimit

# %%
# utilizando os pesos anteriores para predizer as placas na webcam

# !python3 yolov5/detect.py  --source 0 --weight runs/train/exp11/weights/best.pt --img 416 --conf 0.25
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# detect: weights=['runs/train/exp11/weights/best.pt'], source=0, imgsz=416, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /home/vindn/Insync/dalto@cos.ufrj.br/Google Drive/disciplinas/CPS862 - Top. Esp. em Arq. de Prop. Espec./trabalho2/Traffic Signs - Yolov5/requirements.txt not found, check failed.
# YOLOv5 🚀 2021-7-20 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce GTX 1060 3GB, 3019.0625MB)
#
# Fusing layers...
# ...
